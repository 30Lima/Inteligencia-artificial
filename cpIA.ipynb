# %% [markdown]
# Nome dos integrantes:
# Pedro Henrique Lima Santos  (RM558243), Vitor Gomes Martins (RM558244), Leornardo Pimentel Santos(RM557541)
# ---
#
#
#
#
# Turma: 1TDSPX
#
# link do dataset: https://www.kaggle.com/datasets/valakhorasani/gym-members-exercise-dataset?resource=download
#
# OBS.: Professor, caso dê algum problema na importação do dataset, deixamos o link para o senhor fazer download do arquivo .csv
#
# Também deixamos o código bem organizado e seguimos o passo a passo que o senhor disponibilizou no teams.

# %%
#importando as lib necessárias
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('/content/gym_members_exercise_tracking.csv')
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[5], line 2
#
#       1 #importando as lib necessárias
#
# ----> 2 import matplotlib as plt
#
#       3 import pandas as pd
#
#       4 import numpy as np
#
#
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# Agora, iremos fazer a primeira análise do dataset e depois definir a qeustão a ser respondida.

# %%
# Analisando as primeiras linhas do dataset
print("Primeiras linhas do dataset:")
print(df.head())
# Out:
# Primeiras linhas do dataset:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
# ...

# %%
# Verificando a estrutura do dataset
print("\nInformações sobre o dataset:")
print(df.info())
# Out:
# Informações sobre o dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
# ...

# %%
# Resumo estatístico para variáveis numéricas
print("\nResumo estatístico das variáveis numéricas:")
print(df.describe())
# Out:
# Resumo estatístico das variáveis numéricas:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %%
# Visualizar os tipos de dados das colunas
print("\nTipos de dados das colunas:")
print(df.dtypes)
# Out:
# Tipos de dados das colunas:
# Age                                int64
# Gender                            object
# Weight (kg)                      float64
# Height (m)                       float64
# Max_BPM                            int64
# Avg_BPM                            int64
# Resting_BPM                        int64
# Session_Duration (hours)         float64
# Calories_Burned                  float64
# Workout_Type                      object
# Fat_Percentage                   float64
# Water_Intake (liters)            float64
# Workout_Frequency (days/week)      int64
# Experience_Level                   int64
# BMI                              float64
# dtype: object

# %%
# Contar o número de linhas e colunas
num_linhas, num_colunas = df.shape
print(f"\nO dataset contém {num_linhas} linhas e {num_colunas} colunas.")
# Out:
# O dataset contém 973 linhas e 15 colunas.

# %%
# Verificar se há dados faltantes
print("Verificando dados faltantes:")
print(df.isnull().sum())
# Out:
# Verificando dados faltantes:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %% [markdown]
# OBS.: Após a análise de dados faltantes, foi possível verificar que não há nenhum dado faltante no dataset escolhido.
# Então, não é necessário tratá-los.

# %% [markdown]
# QUESTÃO A SER RESPONDIDA:
# Com base no gênero da pessoa, a queima de calorias tem variações ou são relativamente parecidas quando ambos estão na academia?

# %% [markdown]
# Após a análise inicial do dataset e também a definição da questão a ser respondida, decidimos realizar um gráfico de dispersão

# %%
# Gráficos de dispersão
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='Calories_Burned', hue='Gender')
plt.title('Calorias queimada em relação à idade')
plt.xlabel('Idade')
plt.ylabel('Calorias queimada')
plt.show()

# %% [markdown]
# Com base no gráfico de dispersão, podemos definir que, entre 1400 e 500 calorias, homens e mulheres ficam no mesmo patamar quando estão realizando algum treino na academia.
#
# Por mais que no gráfico tenhamos uma quantidade relativa de pessoas do gênero masculino, percebemos também que as mulheres entre 20 e 60 anos queimam menos calorias do que homens da mesma idade.
#
# Um fator interessante é que este gráfico surpreende bastante, pois nós, do grupo, achamos que as mulheres não queimavam tantas calorias na academia em relação aos homens, mas, na verdade, os dados ficam "acirrados".
#
# Sinceramente, não achamos que há algum outlier no gráfico, porque os únicos dados distantes estão após 1650 (aproximadamente).
#
# Resposta à pergunta:
# A queima de calorias quando um homem ou mulher está na academia é relativamente parecida, conforme mostrado no gráfico acima.
